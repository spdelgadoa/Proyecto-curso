# %%
import pandas as pd
import numpy as np

df_books = pd.read_csv('/Users/sandradelgadoalmendrales/Library/Mobile Documents/com~apple~CloudDocs/Platzi /Numpy y Pandas/Proyecto curso/Pandas/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv')

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %% [markdown]
# Drop columns
#
# Recordemos que eje 1 = columnas 0 = filas
#
# Si queremos que lo borre del dataframe original se agrega "inplace=True"
#
# 1. df_books.drop('Genre',axis=1).head(2)

# %%
df_books.drop('Genre',axis=1,inplace=True)

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %% [markdown]
# Asociandolo al dataframe también hace el borrado

# %%
df_books = df_books.drop('Year',axis=1)

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22

# %%
del df_books['Price']

# %% [markdown]
# Drop Rows

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
df_books.drop([0,1,2],axis=0).head(2)
# Out:
#                                                 Name  \
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df_books.drop(range(0,10),axis=0).head(2)
# Out:
#                                                  Name            Author  \
# 10                          A Man Called Ove: A Novel   Fredrik Backman
# 11  A Patriot's History of the United States: From...  Larry Schweikart
#
#     User Rating  Reviews  Price  Year        Genre
# 10          4.6    23848      8  2017      Fiction
# 11          4.6      460      2  2010  Non Fiction

# %% [markdown]
# Add columns

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
df_books['Nueva Columna'] = np.nan
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre  Nueva Columna
# 0  2016  Non Fiction            NaN
# 1  2011      Fiction            NaN

# %%
data = np.arange(0,df_books.shape[0])

# %%
df_books['Rango'] = data

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# Add Rows

# %%
#append not working anymore use instead --> pd.concat
#new_row={'Name':'Ejemplo', 'Author':'El Autor','Year':2024}
#new_row_df = pd.DataFrame([new_row])
df_books = pd.concat([df_books, df_books], ignore_index=True)
df_books
# Out:
#                                                    Name  \
# 0                         10-Day Green Smoothie Cleanse
# 1                                     11/22/63: A Novel
# 2               12 Rules for Life: An Antidote to Chaos
# 3                                1984 (Signet Classics)
# 4     5,000 Awesome Facts (About Everything!) (Natio...
# ...                                                 ...
# 1095       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 1096  You Are a Badass: How to Stop Doubting Your Gr...
# 1097  You Are a Badass: How to Stop Doubting Your Gr...
# 1098  You Are a Badass: How to Stop Doubting Your Gr...
# 1099  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Author  User Rating  Reviews  Price  Year        Genre
# 0                     JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                 Stephen King          4.6     2052     22  2011      Fiction
# ...
